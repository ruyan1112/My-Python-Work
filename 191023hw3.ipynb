# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import sympy as sp
from sympy.abc import x,y,z,a,b,c

# %%
a = np.random.randint(-20, 21)
b = np.random.randint(-20, 21)
c = np.random.randint(-20, 21)
d = np.random.randint(-20, 21)

# %%
y = a*x**3 + b*x**2 + c*x + d

# %%
y
# Out:
# 3*x**3 + 19*x**2 + 20*x + 14

# %%
sp.plot(y)

# %%
g = sp.diff(y)

# %%
g
# Out:
# 9*x**2 + 38*x + 20

# %%
sp.plot(g)

# %%
h = sp.diff(g)

# %%
h
# Out:
# 18*x + 38

# %%
sp.plot(h)
