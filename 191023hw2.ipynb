# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
P = np.random.randn(200, 2)

# %%
cl = np.random.randint(1, 13, 200)

# %%
plt.scatter(P[:,0], P[:,1], c = cl, s = 100, alpha = 0.75, cmap = 'Set3')
