# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display, YouTubeVideo

# %%
response = input('''要我來向你推薦一首歌嗎~
(要/不要)''')

Urban = YouTubeVideo("g4uWEaZqP1w")
Dean = YouTubeVideo("eelfrHtmk68")
EddyK = YouTubeVideo("Y4mH2KvzUQ0")
HDGKMK = YouTubeVideo("Iaa1EJvJZbI")
NUEST = YouTubeVideo("bBnWklKfYN0")
BaekYerin = YouTubeVideo("IRNBtocmQ58")
TU = YouTubeVideo("btMEbMtXrY4")
MX = YouTubeVideo("qoST0RCspps")

songslist = [Urban, Dean, EddyK, HDGKMK, NUEST, BaekYerin, TU, MX]

if(response == "不要"):
    print("好吧(๑ ㅠдㅠ)")
elif(response == "要"):
    print("Here it is.٩(๑❛ᴗ❛๑)۶")
    display(np.random.choice(songslist))
else:
    print("好好回答啦!!")
# Out:
# 要我來向你推薦一首歌嗎~
# (要/不要)要
# Here it is.٩(๑❛ᴗ❛๑)۶
